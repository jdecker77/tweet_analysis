# %% [markdown]
# ## NLP
# ---
#
# #### Import files

# %%
# %run -i '../scripts/nlp.py'

# %%
# %run -i '../scripts/config.py'

# %%
df = file_io.ReadCSV('erie_tweets_c1')
# Out:
# filename: ../data/models/erie_tweets_c1.csv

# %%
df.head()
# Out:
#                  id_str                                               text  \
# 12  1094936894213890048                            https://t.co/Zcc1qy2yWZ
# 18  1094937051160563712  @SandaBlue Maybe ten or more of my nature Twit...
# 22  1094937171763609600                              @SandaBlue Lazy fucks
# 24  1094937302625910784          @SandaBlue Definitely! Love those greens!
# 42  1094938290036330496  @SandaBlue And one of the things we were all t...
#
#     created_hr created_dotw                    calltime  day  set  call  \
# 12           7          Mon  2019-02-11 07:55:38.984121   11    1     1
# 18           7          Mon  2019-02-11 07:55:38.984121   11    1     1
# 22           7          Mon  2019-02-11 07:55:38.984121   11    1     1
# 24           7          Mon  2019-02-11 07:55:38.984121   11    1     1
# 42           7          Mon  2019-02-11 07:55:38.984121   11    1     1
#
#     favorite_count  retweet_count        ...         profile_background_color  \
# 12               0              0        ...                           000000
# 18               0              0        ...                           C0DEED
# 22               0              0        ...                           C0DEED
# 24               0              0        ...                           C0DEED
# 42               0              0        ...                           C0DEED
#
#    profile_text_color user_screen_name  statuses_count  verified  num_tags  \
# 12             000000    wynterdawn_07           13278     False         0
# 18             333333      JamesIsaak2          216043     False         0
# 22             333333      JamesIsaak2          216044     False         0
# 24             333333      JamesIsaak2          216045     False         0
# 42             333333      JamesIsaak2          216046     False         0
#
#    num_media  num_symbols  num_urls  num_user_mentions
# 12         0            0         1                  0
# 18         0            0         1                  1
# 22         0            0         0                  1
# 24         0            0         0                  1
# 42         0            0         1                  1
#
# [5 rows x 39 columns]

# %%
'''
Subset single day
'''
df = df[df['set'] == 1]

# %%
df.describe()
# Out:
#              id_str  created_hr        day   set  call  favorite_count  \
# count  3.900000e+01        39.0  39.000000  39.0  39.0            39.0
# mean   1.095934e+18         7.0  13.743590   1.0   1.0             0.0
# std    7.792139e+14         0.0   2.148659   0.0   0.0             0.0
# min    1.094937e+18         7.0  11.000000   1.0   1.0             0.0
# 25%    1.095122e+18         7.0  11.500000   1.0   1.0             0.0
# 50%    1.096028e+18         7.0  14.000000   1.0   1.0             0.0
# 75%    1.096749e+18         7.0  16.000000   1.0   1.0             0.0
# max    1.097118e+18         7.0  17.000000   1.0   1.0             0.0
#
#        retweet_count  influence_score  in_reply_to_status_id_str  \
# count           39.0        39.000000               1.200000e+01
# mean             0.0        21.456410               1.095563e+18
# std              0.0        23.171641               7.572227e+14
# min              0.0         0.650000               1.094935e+18
# 25%              0.0         5.925000               1.094938e+18
# 50%              0.0        13.350000               1.095206e+18
# 75%              0.0        28.862500               1.096109e+18
# max              0.0        70.275000               1.096856e+18
#
#        in_reply_to_user_id_str        ...          favorites_counts  \
# count             1.600000e+01        ...                 39.000000
# mean              6.784949e+16        ...              43287.871795
# std               2.713980e+17        ...              67734.113025
# min               2.535572e+07        ...                106.000000
# 25%               3.822531e+08        ...               1321.500000
# 50%               2.422703e+09        ...               9077.000000
# 75%               2.422703e+09        ...              47343.000000
# max               1.085592e+18        ...             188071.000000
#
#        followers_count  friends_count  listed_count  statuses_count  \
# count        39.000000      39.000000     39.000000       39.000000
# mean        800.333333    1053.307692     19.307692    50359.435897
# std         846.188088    1151.083315     30.551211    77444.219785
# min          26.000000      64.000000      0.000000      182.000000
# 25%         225.000000     179.500000      0.000000     2792.500000
# 50%         450.000000     618.000000      4.000000    13278.000000
# 75%        1072.000000    1299.000000     15.000000    48073.000000
# max        2562.000000    3393.000000     83.000000   216048.000000
#
#         num_tags  num_media  num_symbols   num_urls  num_user_mentions
# count  39.000000  39.000000         39.0  39.000000          39.000000
# mean    0.128205   0.076923          0.0   0.461538           0.512821
# std     0.409074   0.269953          0.0   0.505035           0.555915
# min     0.000000   0.000000          0.0   0.000000           0.000000
# 25%     0.000000   0.000000          0.0   0.000000           0.000000
# 50%     0.000000   0.000000          0.0   0.000000           0.000000
# 75%     0.000000   0.000000          0.0   1.000000           1.000000
# max     2.000000   1.000000          0.0   1.000000           2.000000
#
# [8 rows x 22 columns]

# %% [markdown]
# ### Wordmaps and Frequency Tables

# %%
'''
Set 1 
7:30 AM
'''
set_n = 1
setName = 'Set 1 7:30 AM'
text_series = df[df['set']== set_n]

# Get text as list
text_list = text_series['text']

# Get freq table and word clouds
pos_df1,neg_df1 = ExamineText(text_list[:],setName)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/Mercyhurst/CIS_572/final/tw_net/scripts/tw_net_nlp.py in <module>
#      11
#      12 # Get freq table and word clouds
# ---> 13 pos_df1,neg_df1 = ExamineText(text_list[:],setName)
#
# ~/Mercyhurst/CIS_572/final/tw_net/scripts/tw_net_nlp.py in ExamineText(text_list, title)
#     144     ax2.set_title('Negative Sentiment')
#     145     # img = ax2.imshow(wc_neg,interpolation="bilinear")
# --> 146     img = ax2.imshow(wc_neg.recolor(color_func=red_color_func, random_state=3),interpolation="bilinear")
#     147
#     148     pos_df = pos_df.drop_duplicates()
#
# ~/miniconda3/envs/gis/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/miniconda3/envs/gis/lib/python3.6/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5492                               resample=resample, **kwargs)
#    5493
# -> 5494         im.set_data(X)
#    5495         im.set_alpha(alpha)
#    5496         if im.get_clip_path() is None:
#
# ~/miniconda3/envs/gis/lib/python3.6/site-packages/matplotlib/image.py in set_data(self, A)
#     636                 self._A = pil_to_array(A)
#     637         else:
# --> 638             self._A = cbook.safe_masked_invalid(A, copy=True)
#     639
#     640         if (self._A.dtype != np.uint8 and
#
# ~/miniconda3/envs/gis/lib/python3.6/site-packages/matplotlib/cbook/__init__.py in safe_masked_invalid(x, copy)
#     782
#     783 def safe_masked_invalid(x, copy=False):
# --> 784     x = np.array(x, subok=True, copy=copy)
#     785     if not x.dtype.isnative:
#     786         # Note that the argument to `byteswap` is 'inplace',
#
# ~/miniconda3/envs/gis/lib/python3.6/site-packages/wordcloud/wordcloud.py in __array__(self)
#     711             Word cloud image as numpy matrix.
#     712         """
# --> 713         return self.to_array()
#     714
#     715     def to_html(self):
#
# ~/miniconda3/envs/gis/lib/python3.6/site-packages/wordcloud/wordcloud.py in to_array(self)
#     701             Word cloud image as numpy matrix.
#     702         """
# --> 703         return np.array(self.to_image())
#     704
#     705     def __array__(self):
#
# ~/miniconda3/envs/gis/lib/python3.6/site-packages/wordcloud/wordcloud.py in to_image(self)
#     630             pos = (int(position[1] * self.scale),
#     631                    int(position[0] * self.scale))
# --> 632             draw.text(pos, word, fill=color, font=transposed_font)
#     633
#     634         return self._draw_contour(img=img)
#
# ~/miniconda3/envs/gis/lib/python3.6/site-packages/PIL/ImageDraw.py in text(self, xy, text, fill, font, anchor, *args, **kwargs)
#     265             return self.multiline_text(xy, text, fill, font, anchor,
#     266                                        *args, **kwargs)
# --> 267         ink, fill = self._getink(fill)
#     268         if font is None:
#     269             font = self.getfont()
#
# ~/miniconda3/envs/gis/lib/python3.6/site-packages/PIL/ImageDraw.py in _getink(self, ink, fill)
#     108             if ink is not None:
#     109                 if isStringType(ink):
# --> 110                     ink = ImageColor.getcolor(ink, self.mode)
#     111                 if self.palette and not isinstance(ink, numbers.Number):
#     112                     ink = self.palette.getcolor(ink)
#
# ~/miniconda3/envs/gis/lib/python3.6/site-packages/PIL/ImageColor.py in getcolor(color, mode)
#     140     """
#     141     # same as getrgb, but converts the result to the given mode
# --> 142     color, alpha = getrgb(color), 255
#     143     if len(color) == 4:
#     144         color, alpha = color[0:3], color[3]
#
# ~/miniconda3/envs/gis/lib/python3.6/site-packages/PIL/ImageColor.py in getrgb(color)
#     125             int(m.group(4))
#     126             )
# --> 127     raise ValueError("unknown color specifier: %r" % color)
#     128
#     129
#
# ValueError: unknown color specifier: 'hsl(0, 100, 86%)'

# %%
pos_df.head()
# Out:
#              t        tf       idf    tf*idf
# 0    sandablue  0.025253  0.092900  0.002346
# 190       erie  0.020202  0.078828  0.001592
# 31       would  0.015152  0.063480  0.000962
# 34        much  0.015152  0.063480  0.000962
# 138        one  0.015152  0.059121  0.000896

# %%
neg_df.head()
# Out:
#             t        tf       idf    tf*idf
# 21       like  0.041667  0.132419  0.005517
# 43        guy  0.041667  0.132419  0.005517
# 19      think  0.041667  0.132419  0.005517
# 0   sandablue  0.020833  0.080650  0.001680
# 35        nah  0.020833  0.080650  0.001680

# %%
'''
Set 2
9:45 AM
'''
set_n = 2
setName = 'Set 2 9:45 AM'
text_series = df[df['set']== set_n]

# Get text as list
text_list = text_series['text']

# Get freq table and word clouds
pos_df,neg_df = ExamineText(text_list[:],setName)

# %%
pos_df.head()
# Out:
#           t        tf       idf    tf*idf
# 18      wha  0.103448  0.234691  0.024278
# 137    like  0.027586  0.099047  0.002732
# 59    album  0.013793  0.059084  0.000815
# 121  school  0.013793  0.059084  0.000815
# 62     well  0.013793  0.059084  0.000815

# %%
neg_df.head()
# Out:
#            t        tf       idf    tf*idf
# 37      year  0.036810  0.121546  0.004474
# 32      like  0.018405  0.073530  0.001353
# 122   female  0.018405  0.073530  0.001353
# 43   thought  0.012270  0.053995  0.000663
# 59   fucking  0.012270  0.053995  0.000663

# %%
'''
Set 3 
12:00 PM
'''
set_n = 1
setName = 'Set 1'
text_series = df[df['set']== set_n]

# Get text as list
text_list = text_series['text']

# Get freq table and word clouds
set3_freq = ExamineText(text_list[:10],setName)

# %%
set3_freq.head()
